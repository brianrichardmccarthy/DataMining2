# %% [markdown]
# Refs
#
#  * [Hyperopt: A Python Library for Optimizing the Hyperparameters of Machine Learning Algorithms](https://conference.scipy.org/proceedings/scipy2013/pdfs/bergstra_hyperopt.pdf)
#  * [Hyperopt-Sklearn](https://www.ml4aad.org/wp-content/uploads/2018/07/automl_book_draft_hyperopt-sklearn.pdf)

# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ## Load Data and prep data

# %%
DATA_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
DATA_LOCAL = "data/wdbc.data"
SEED = 42

names = ['id_number', 'diagnosis', 'radius_mean', 
         'texture_mean', 'perimeter_mean', 'area_mean', 
         'smoothness_mean', 'compactness_mean', 'concavity_mean',
         'concave_points_mean', 'symmetry_mean', 
         'fractal_dimension_mean', 'radius_se', 'texture_se', 
         'perimeter_se', 'area_se', 'smoothness_se', 
         'compactness_se', 'concavity_se', 'concave_points_se', 
         'symmetry_se', 'fractal_dimension_se', 
         'radius_worst', 'texture_worst', 'perimeter_worst',
         'area_worst', 'smoothness_worst', 
         'compactness_worst', 'concavity_worst', 
         'concave_points_worst', 'symmetry_worst', 
         'fractal_dimension_worst'] 

df = pd.read_csv(DATA_LOCAL,header=None, names=names)

# %%
X = df.iloc[:, 2:].values
y = df.diagnosis.values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=SEED)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %% [markdown]
# ## Hyperopt

# %% [markdown]
# ### Simple (to the point of stupid) Example

# %%
from hyperopt import hp

# %% [markdown]
# Step 1: Define objective function
#
# The objective function is function we wish to maxamise/minimise.

# %%
def obj(args):
    x, y = args
    return x**2 + y**2

# %% [markdown]
# Aside: plot function to show how smooth and easy it is

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure()
ax = fig.gca(projection='3d')
xs = np.arange(-1, 1, 0.25)
ys = np.arange(-1, 1, 0.25)
xs, ys = np.meshgrid(xs, ys)
zs = (xs**2 + ys**2)
surf = ax.plot_surface(xs, ys, zs, cmap=cm.coolwarm,linewidth=0, antialiased=False)

plt.show()

# %% [markdown]
# Step 2: Define a configuration space
#
# A configuration space is a region (domain) over which the search is performed. for each parameter specify its distribution.cs

# %%
space = [hp.normal('x', 0,1), hp.uniform('y',-2, 1)]

# %% [markdown]
# Step 3: Choose a search algorithm

# %%
from hyperopt import hp, fmin, rand, tpe, space_eval 
best = fmin(obj, space, algo=rand.suggest, max_evals=100)
print (best)

print ("rand", space_eval(space, best))
best = fmin(obj, space, algo=tpe.suggest, max_evals=100)
print (best)
print ("tpe", space_eval(space, best))
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1543.19it/s, best loss: 0.04219949674910985]
# {'x': -0.12504205662012438, 'y': 0.16298460303145035}
# rand (-0.12504205662012438, 0.16298460303145035)
# 100%|██████████| 100/100 [00:00<00:00, 384.15it/s, best loss: 0.0005961443300483466]
# {'x': 0.010437987834572723, 'y': -0.022072443000575592}
# tpe (0.010437987834572723, -0.022072443000575592)

# %%
from hyperopt import Trials
trials = Trials()

best = fmin(obj, space, algo=tpe.suggest, max_evals=10, trials=trials)
print (best)
print ("tpe", space_eval(space, best))
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 831.81it/s, best loss: 0.1443624684028026]
# {'x': 0.03134513945280643, 'y': 0.37865545108381404}
# tpe (0.03134513945280643, 0.37865545108381404)

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 0.1443624684028026, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [0], 'y': [0]},
#    'vals': {'x': [0.03134513945280643], 'y': [0.37865545108381404]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 246000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 246000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 3.23284404867748, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [1], 'y': [1]},
#    'vals': {'x': [-0.7204040778947302], 'y': [-1.6473803486839715]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 247000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 247000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 2.0290916426833614, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [2], 'y': [2]},
#    'vals': {'x': [0.6626145955170929], 'y': [-1.2609653208915306]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 248000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 248000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 2.812008846610311, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [3], 'y': [3]},
#    'vals': {'x': [-1.5156829173831932], 'y': [-0.7174358093676974]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 249000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 249000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 1.9489007589550797, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [4], 'y': [4]},
#    'vals': {'x': [-1.1907943556888076], 'y': [0.7286354104864499]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 250000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 250000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 0.40365752511047626, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [5], 'y': [5]},
#    'vals': {'x': [0.4727834137454018], 'y': [-0.42442121624362805]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 251000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 252000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 0.5029557953045226, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [6], 'y': [6]},
#    'vals': {'x': [0.696587142944194], 'y': [0.13312455667294287]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 253000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 253000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 1.6740004395844124, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [7], 'y': [7]},
#    'vals': {'x': [0.8763833223979306], 'y': [0.9518154820169595]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 254000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 254000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 2.5844248153987537, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [8], 'y': [8]},
#    'vals': {'x': [-0.0615596400161961], 'y': [-1.6064355655051434]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 255000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 255000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 0.7157683566122544, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [9], 'y': [9]},
#    'vals': {'x': [0.6745188330071921], 'y': [-0.5106786666102963]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 256000),
#   'refresh_time': datetime.datetime(2019, 2, 26, 10, 47, 47, 256000)}]

# %% [markdown]
# ## Example 2

# %%
from hyperopt import anneal, rand, tpe, mix
from hpsklearn import HyperoptEstimator, partial
# Out:
# WARN: OMP_NUM_THREADS=None =>
# ... If you are using openblas if you are using openblas set OMP_NUM_THREADS=1 or risk subprocess calls hanging indefinitely

# %% [markdown]
# Define an algorithm that searches randomly 5% of the time, uses Tree-structured Parzen Estimator (TPE) 75% of the time, and uses simulated annealing 20% of the time.

# %%
mix_algo = partial(mix.suggest, p_suggest=[
    (0.05, rand.suggest),
    (0.75, tpe.suggest),
    (0.20, anneal.suggest)])

# %%
from hpsklearn import svc_rbf
estimate = HyperoptEstimator(
    classifier=svc_rbf("my_svc"), 
    algo=mix_algo,
    max_evals=150,
    trial_timeout=60)
estimate.fit(X_train_scaled, y_train)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 28.56it/s, best loss: 0.3626373626373627]
# 100%|██████████| 1/1 [00:00<00:00, 17.27it/s, best loss: 0.3626373626373627]
# 100%|██████████| 1/1 [00:00<00:00, 34.91it/s, best loss: 0.3626373626373627]
# 100%|██████████| 1/1 [00:00<00:00, 28.63it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 27.35it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 27.93it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 25.44it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 28.95it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.86it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 24.65it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 15.44it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 24.05it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 14.36it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 35.01it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 35.47it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 31.94it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 32.31it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 31.65it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 18.41it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 28.52it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00,  8.49it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.89it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 29.14it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.54it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 36.70it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.64it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 24.90it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.01it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.77it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.87it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 37.43it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.71it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 16.53it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 34.60it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 22.11it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 24.32it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 23.59it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.12it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.41it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 20.33it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.78it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 22.38it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 13.13it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 18.57it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 15.26it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 15.97it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 17.36it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 22.13it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 21.15it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 23.00it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 13.79it/s, best loss: 0.04395604395604391]
# 100%|██████████| 1/1 [00:00<00:00, 19.25it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 16.79it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 18.10it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 16.48it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.69it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 13.18it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 31.34it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 22.75it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.12it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 12.86it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.25it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.08it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.38it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 16.46it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 20.49it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 22.52it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 23.37it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.40it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 30.68it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 18.01it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 20.83it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 20.69it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.96it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.94it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 16.13it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 18.30it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.01it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 20.06it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 31.38it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 27.67it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.62it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 18.46it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.73it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 21.05it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.68it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 19.75it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 15.51it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 29.52it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 29.57it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 29.23it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 24.88it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 16.59it/s, best loss: 0.03296703296703296]
# 100%|██████████| 1/1 [00:00<00:00, 18.66it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 21.09it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 16.62it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 25.14it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 30.55it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 11.42it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 15.55it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 27.08it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 17.49it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 11.19it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 16.99it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 16.75it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 15.09it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 23.10it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 25.42it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.61it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 12.57it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 16.53it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 14.44it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 16.36it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 13.53it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 14.52it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 15.11it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 14.23it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 23.63it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 14.78it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 25.37it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 23.69it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  8.81it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  2.21it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.78it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.86it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.96it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.54it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.89it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 19.10it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  3.38it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 10.94it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 10.58it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 10.72it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 12.22it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 26.59it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 11.71it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 22.75it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00,  9.63it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 24.11it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 22.48it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 13.05it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 12.89it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 11.61it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 22.55it/s, best loss: 0.02197802197802201]
# 100%|██████████| 1/1 [00:00<00:00, 24.98it/s, best loss: 0.02197802197802201]

# %%
print(estimate.score(X_test_scaled, y_test))
print(estimate.best_model())
# Out:
# 0.9824561403508771
# {'learner': SVC(C=18.82666607535831, cache_size=512, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=1, gamma=0.02339235968169092,
#   kernel='rbf', max_iter=43120254.0, probability=False, random_state=0,
#   shrinking=True, tol=0.00024399815162693506, verbose=False), 'preprocs': (Normalizer(copy=True, norm='l2'),), 'ex_preprocs': ()}
